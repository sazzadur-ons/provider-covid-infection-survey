# %%
import pandas as pd

# %%
df = pd.read_excel(io="20230113covid19infectionsurveydatasetengland.xlsx", sheet_name="1a", skiprows=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df = pd.read_excel(io="20230113covid19infectionsurveydatasetengland.xlsx", sheet_name="1a", skiprows=4)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
# ...

# %%
df = pd.read_excel(io="20230113covid19infectionsurveydatasetsengland.xlsx", sheet_name="1a", skiprows=4)

# %%
df
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df["Time period"]
# Out:
# 0              27 April 2020 to 10 May 2020
# 1                04 May 2020 to 17 May 2020
# 2                11 May 2020 to 24 May 2020
# 3                17 May 2020 to 30 May 2020
# 4               25 May 2020 to 07 June 2020
#                        ...
# 134    20 November 2022 to 26 November 2022
# 135    29 November 2022 to 05 December 2022
# 136    03 December 2022 to 09 December 2022
# 137    22 December 2022 to 28 December 2022
# 138     28 December 2022 to 03 January 2023
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].split(" to ")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 df["Time period"].split(" to ")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5482'>5483</a>     and name not in self._accessors
# ...

# %%
df["Time period"].str.split(" to ")
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")[0]
# Out:
# ['27 April 2020', '10 May 2020']

# %%
df["Time period"].str.split(" to ")[,0]
# Out:
#   Input In [9]
#     df["Time period"].str.split(" to ")[,0]
#                                         ^
# SyntaxError: invalid syntax

# %%
df["Time period"].str.split(" to ")[:,0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 df["Time period"].str.split(" to ")[:,0]
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/series.py:966, in Series.__getitem__(self, key)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/series.py?line=962'>963</a>     key = np.asarray(key, dtype=bool)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/series.py?line=963'>964</a>     return self._get_values(key)
# --> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/series.py?line=965'>966</a> return self._get_with(key)
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/series.py:981, in Series._get_with(self, key)
# ...

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y=[0] for y in list(x)])
# Out:
#   Input In [11]
#     df["Time period"].str.split(" to ").apply(lambda x: [y=[0] for y in list(x)])
#                                                          ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y[0] for y in list(x)])
# Out:
# 0      [2, 1]
# 1      [0, 1]
# 2      [1, 2]
# 3      [1, 3]
# 4      [2, 0]
#         ...
# 134    [2, 2]
# 135    [2, 0]
# 136    [0, 0]
# 137    [2, 2]
# 138    [2, 0]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y[0] for y in list(x)])
# Out:
# 0      [2, 1]
# 1      [0, 1]
# 2      [1, 2]
# 3      [1, 3]
# 4      [2, 0]
#         ...
# 134    [2, 2]
# 135    [2, 0]
# 136    [0, 0]
# 137    [2, 2]
# 138    [2, 0]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ").apply(lambda x: [y[0] for y in x])
# Out:
# 0      [2, 1]
# 1      [0, 1]
# 2      [1, 2]
# 3      [1, 3]
# 4      [2, 0]
#         ...
# 134    [2, 2]
# 135    [2, 0]
# 136    [0, 0]
# 137    [2, 2]
# 138    [2, 0]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ")[0]
# Out:
# ['27 April 2020', '10 May 2020']

# %%
df["Time period"].str.split(" to ", n=1)
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ", n=0)
# Out:
# 0              [27 April 2020, 10 May 2020]
# 1                [04 May 2020, 17 May 2020]
# 2                [11 May 2020, 24 May 2020]
# 3                [17 May 2020, 30 May 2020]
# 4               [25 May 2020, 07 June 2020]
#                        ...
# 134    [20 November 2022, 26 November 2022]
# 135    [29 November 2022, 05 December 2022]
# 136    [03 December 2022, 09 December 2022]
# 137    [22 December 2022, 28 December 2022]
# 138     [28 December 2022, 03 January 2023]
# Name: Time period, Length: 139, dtype: object

# %%
df["Time period"].str.split(" to ", expand=True)
# Out:
#                     0                 1
# 0       27 April 2020       10 May 2020
# 1         04 May 2020       17 May 2020
# 2         11 May 2020       24 May 2020
# 3         17 May 2020       30 May 2020
# 4         25 May 2020      07 June 2020
# ..                ...               ...
# 134  20 November 2022  26 November 2022
# 135  29 November 2022  05 December 2022
# 136  03 December 2022  09 December 2022
# 137  22 December 2022  28 December 2022
# 138  28 December 2022   03 January 2023
#
# [139 rows x 2 columns]

# %%
df.join(df["Time period"].str.split(" to ", expand=True))
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df2 = df.join(df["Time period"].str.split(" to ", expand=True))

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df2.rename(columns={"0": "start_date", "1": "end_date"})
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df2 = df2.rename(columns={"0": "start_date", "1": "end_date"})

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df2 = df2.rename(columns={0: "start_date", 1: "end_date"})

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df2["start_date"]
# Out:
# 0         27 April 2020
# 1           04 May 2020
# 2           11 May 2020
# 3           17 May 2020
# 4           25 May 2020
#              ...
# 134    20 November 2022
# 135    29 November 2022
# 136    03 December 2022
# 137    22 December 2022
# 138    28 December 2022
# Name: start_date, Length: 139, dtype: object

# %%
pd.to_datetime(df2["start_date"])
# Out:
# 0     2020-04-27
# 1     2020-05-04
# 2     2020-05-11
# 3     2020-05-17
# 4     2020-05-25
#          ...
# 134   2022-11-20
# 135   2022-11-29
# 136   2022-12-03
# 137   2022-12-22
# 138   2022-12-28
# Name: start_date, Length: 139, dtype: datetime64[ns]

# %%
df2["start_date"] = pd.to_datetime(df2["start_date"])

# %%
df2["start_date"].year
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 df2["start_date"].year
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5482'>5483</a>     and name not in self._accessors
# ...

# %%
df2["start_date"].dt.year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 134    2022
# 135    2022
# 136    2022
# 137    2022
# 138    2022
# Name: start_date, Length: 139, dtype: int64

# %%
df2["start_date"].dt.week
# Out:
# <ipython-input-33-13530e5c238e>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2["start_date"].dt.week
# 0      18
# 1      19
# 2      20
# 3      20
# 4      22
#        ..
# 134    46
# 135    48
# 136    48
# 137    51
# 138    52
# Name: start_date, Length: 139, dtype: int64

# %%
df2["start_date"].dt.year + "-" + df2["start_date"].dt.week
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 df2["start_date"].dt.year + "-" + df2["start_date"].dt.week
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/ops/common.py:69, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/ops/common.py?line=64'>65</a>             return NotImplemented
#      <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/ops/common.py?line=66'>67</a> other = item_from_zerodim(other)
# ---> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/ops/common.py?line=68'>69</a> return method(self, other)
#
# ...

# %%
join([df2["start_date"].dt.year,"-",df2["start_date"].dt.week])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 1>()
# ----> 1 join([df2["start_date"].dt.year,"-",df2["start_date"].dt.week])
#
# NameError: name 'join' is not defined

# %%
([df2["start_date"].dt.year,"-",df2["start_date"].dt.week]).join()
# Out:
# <ipython-input-36-dc1180916150>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   ([df2["start_date"].dt.year,"-",df2["start_date"].dt.week]).join()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 ([df2["start_date"].dt.year,"-",df2["start_date"].dt.week]).join()
#
# AttributeError: 'list' object has no attribute 'join'

# %%
df2["start_date_year"] = df2["start_date"].dt.year

# %%
df2["start_date_week"] = df2["start_date"].dt.week
# Out:
# <ipython-input-38-e02598bd8bd5>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2["start_date_week"] = df2["start_date"].dt.week

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
df2["start_date_year"].str.cat(df2["start_date_week"], sep="-")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 df2["start_date_year"].str.cat(df2["start_date_week"], sep="-")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
# ...

# %%
df2["start_date_year"].str.cat(df2["start_date_week"].str, sep="-")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 df2["start_date_year"].str.cat(df2["start_date_week"].str, sep="-")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
# ...

# %%
df2["start_date_year"].as_type("str")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df2["start_date_year"].as_type("str")
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py:5487, in NDFrame.__getattr__(self, name)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5479'>5480</a> if (
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5480'>5481</a>     name not in self._internal_names_set
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5481'>5482</a>     and name not in self._metadata
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/generic.py?line=5482'>5483</a>     and name not in self._accessors
# ...

# %%
df2["start_date_year"].astype("str")
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 134    2022
# 135    2022
# 136    2022
# 137    2022
# 138    2022
# Name: start_date_year, Length: 139, dtype: object

# %%
df2["start_date_year"] = df2["start_date_year"].astype("str")

# %%
df2["start_date_week"] = df2["start_date_week"].astype("str")

# %%
df2["start_date_year"].str.cat(df2["start_date_week"].str, sep="-")
# Out:
# /Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/strings/accessor.py:393: FutureWarning: Columnar iteration over characters will be deprecated in future releases.
#   others = list(others)  # ensure iterators do not get read twice etc
# 0      2020-1-8
# 1      2020-1-9
# 2      2020-2-0
# 3      2020-2-0
# 4      2020-2-2
#          ...
# 134    2022-4-6
# 135    2022-4-8
# 136    2022-4-8
# 137    2022-5-1
# 138    2022-5-2
# Name: start_date_year, Length: 139, dtype: object

# %%
df2["start_date_week"]
# Out:
# 0      18
# 1      19
# 2      20
# 3      20
# 4      22
#        ..
# 134    46
# 135    48
# 136    48
# 137    51
# 138    52
# Name: start_date_week, Length: 139, dtype: object

# %%
df2["start_date_year"].str.cat(df2["start_date_week"], sep="-")
# Out:
# 0      2020-18
# 1      2020-19
# 2      2020-20
# 3      2020-20
# 4      2020-22
#         ...
# 134    2022-46
# 135    2022-48
# 136    2022-48
# 137    2022-51
# 138    2022-52
# Name: start_date_year, Length: 139, dtype: object

# %%
df2["week"] = df2["start_date_year"].str.cat(df2["start_date_week"], sep="-")

# %%
df2
# Out:
#                               Time period  \
# 0            27 April 2020 to 10 May 2020
# 1              04 May 2020 to 17 May 2020
# 2              11 May 2020 to 24 May 2020
# 3              17 May 2020 to 30 May 2020
# 4             25 May 2020 to 07 June 2020
# ..                                    ...
# 134  20 November 2022 to 26 November 2022
# 135  29 November 2022 to 05 December 2022
# 136  03 December 2022 to 09 December 2022
# 137  22 December 2022 to 28 December 2022
# 138   28 December 2022 to 03 January 2023
#
#      Estimated average % of the population testing positive for COVID-19  \
# 0                                                 0.27
# 1                                                 0.25
# 2                                                 0.24
# 3                                                 0.10
# 4                                                 0.06
# ..                                                 ...
# ...

# %%
{"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",}
# Out:
# {'Estimated average % of the population testing positive for COVID-19': 'percentage_pop_est'}

# %%
{   "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est_lci"

}
# Out:
# {'Estimated average % of the population testing positive for COVID-19': 'percentage_pop_est_lci'}

# %%
{   "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    "95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    "Estimated average number of people testing positive for COVID-19": "pop_est",
    "95% Lower confidence/credible interval for number": "pop_est_lci",
    "95% Upper confidence/credible interval for number": "pop_est_uci",
}
# Out:
# {'Estimated average % of the population testing positive for COVID-19': 'percentage_pop_est',
#  '95% Lower confidence/credible interval for percentage': 'percentage_pop_est_lci',
#  '95% Upper confidence/credible interval for percentage': 'percentage_pop_est_uci',
#  'Estimated average number of people testing positive for COVID-19': 'pop_est',
#  '95% Lower confidence/credible interval for number': 'pop_est_lci',
#  '95% Upper confidence/credible interval for number': 'pop_est_uci'}

# %%
rename_columns = {   "Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    "95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    "Estimated average number of people testing positive for COVID-19": "pop_est",
    "95% Lower confidence/credible interval for number": "pop_est_lci",
    "95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename{columns=rename_columns}
# Out:
#   Input In [55]
#     df2.rename{columns=rename_columns}
#                ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 2              11 May 2020 to 24 May 2020                0.24
# 3              17 May 2020 to 30 May 2020                0.10
# 4             25 May 2020 to 07 June 2020                0.06
# ..                                    ...                 ...
# 134  20 November 2022 to 26 November 2022                1.73
# 135  29 November 2022 to 05 December 2022                2.01
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  \
# 0                      0.17                    0.41
# 1                      0.16                    0.38
# 2                      0.11                    0.46
# ...

# %%
rename_columns = {   r"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    "95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    "95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    "Estimated average number of people testing positive for COVID-19": "pop_est",
    "95% Lower confidence/credible interval for number": "pop_est_lci",
    "95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 2              11 May 2020 to 24 May 2020                0.24
# 3              17 May 2020 to 30 May 2020                0.10
# 4             25 May 2020 to 07 June 2020                0.06
# ..                                    ...                 ...
# 134  20 November 2022 to 26 November 2022                1.73
# 135  29 November 2022 to 05 December 2022                2.01
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  \
# 0                      0.17                    0.41
# 1                      0.16                    0.38
# 2                      0.11                    0.46
# ...

# %%
rename_columns = {   r"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    r"95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    r"95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    r"Estimated average number of people testing positive for COVID-19": "pop_est",
    r"95% Lower confidence/credible interval for number": "pop_est_lci",
    r"95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 2              11 May 2020 to 24 May 2020                0.24
# 3              17 May 2020 to 30 May 2020                0.10
# 4             25 May 2020 to 07 June 2020                0.06
# ..                                    ...                 ...
# 134  20 November 2022 to 26 November 2022                1.73
# 135  29 November 2022 to 05 December 2022                2.01
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  \
# 0                      0.17                    0.41
# 1                      0.16                    0.38
# 2                      0.11                    0.46
# ...

# %%
df2.columns
# Out:
# Index(['Time period',
#        'Estimated average % of the population testing positive for COVID-19',
#        '95% Lower confidence/credible interval for percentage',
#        '95% Upper confidence/credible interval for percentage',
#        ' Estimated average number of people testing positive for COVID-19',
#        '95% Lower confidence/credible interval for number',
#        '95% Upper confidence/credible interval for number',
#        'Estimated average ratio of the population testing positive for COVID-19',
#        '95% Lower confidence/credible interval for ratio',
#        '95% Upper confidence/credible interval for ratio', 'start_date',
#        'end_date', 'start_date_year', 'start_date_week', 'week'],
#       dtype='object')

# %%
rename_columns = {   r"Estimated average % of the population testing positive for COVID-19": "percentage_pop_est",
    r"95% Lower confidence/credible interval for percentage": "percentage_pop_est_lci",
    r"95% Upper confidence/credible interval for percentage": "percentage_pop_est_uci",
    r" Estimated average number of people testing positive for COVID-19": "pop_est",
    r"95% Lower confidence/credible interval for number": "pop_est_lci",
    r"95% Upper confidence/credible interval for number": "pop_est_uci",
}

# %%
df2.rename(columns=rename_columns)
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 2              11 May 2020 to 24 May 2020                0.24
# 3              17 May 2020 to 30 May 2020                0.10
# 4             25 May 2020 to 07 June 2020                0.06
# ..                                    ...                 ...
# 134  20 November 2022 to 26 November 2022                1.73
# 135  29 November 2022 to 05 December 2022                2.01
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# ...

# %%
df2 = df2.rename(columns=rename_columns)

# %%
df2
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 2              11 May 2020 to 24 May 2020                0.24
# 3              17 May 2020 to 30 May 2020                0.10
# 4             25 May 2020 to 07 June 2020                0.06
# ..                                    ...                 ...
# 134  20 November 2022 to 26 November 2022                1.73
# 135  29 November 2022 to 05 December 2022                2.01
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# ...

# %%
df2.columns
# Out:
# Index(['Time period', 'percentage_pop_est', 'percentage_pop_est_lci',
#        'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci',
#        'Estimated average ratio of the population testing positive for COVID-19',
#        '95% Lower confidence/credible interval for ratio',
#        '95% Upper confidence/credible interval for ratio', 'start_date',
#        'end_date', 'start_date_year', 'start_date_week', 'week'],
#       dtype='object')

# %%
df2["week", 'percentage_pop_est', 'percentage_pop_est_lci',
       'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3359'>3360</a> try:
# -> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3360'>3361</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3361'>3362</a> except KeyError as err:
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df2.loc["week", 'percentage_pop_est', 'percentage_pop_est_lci',
       'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 df2.loc["week", 'percentage_pop_est', 'percentage_pop_est_lci',
#       2        'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py:925, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=922'>923</a>         with suppress(KeyError, IndexError):
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=923'>924</a>             return self.obj._get_value(*key, takeable=self._takeable)
# ...

# %%
df2.loc[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [69], in <cell line: 1>()
# ----> 1 df2.loc[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py:931, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=927'>928</a> axis = self.axis or 0
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=929'>930</a> maybe_callable = com.apply_if_callable(key, self.obj)
# --> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=930'>931</a> return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
#         week  percentage_pop_est  percentage_pop_est_lci  \
# 0    2020-18                0.27                    0.17
# 1    2020-19                0.25                    0.16
# 2    2020-20                0.24                    0.11
# 3    2020-20                0.10                    0.05
# 4    2020-22                0.06                    0.02
# ..       ...                 ...                     ...
# 134  2022-46                1.73                    1.60
# 135  2022-48                2.01                    1.87
# 136  2022-48                2.20                    2.08
# 137  2022-51                4.52                    4.29
# 138  2022-52                4.02                    3.84
#
#      percentage_pop_est_uci  pop_est  pop_est_lci  pop_est_uci
# 0                      0.41   148000        94000       222000
# 1                      0.38   137000        85000       208000
# 2                      0.46   133000        62000       250000
# ...

# %%
df2["week", 'percentage_pop_est', 'percentage_pop_est_lci',
       'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3359'>3360</a> try:
# -> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3360'>3361</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexes/base.py?line=3361'>3362</a> except KeyError as err:
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/_libs/index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df2.loc[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [72], in <cell line: 1>()
# ----> 1 df2.loc[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py:931, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=927'>928</a> axis = self.axis or 0
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=929'>930</a> maybe_callable = com.apply_if_callable(key, self.obj)
# --> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=930'>931</a> return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df2.loc[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 df2.loc[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
#
# File ~/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py:931, in _LocationIndexer.__getitem__(self, key)
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=927'>928</a> axis = self.axis or 0
#     <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=929'>930</a> maybe_callable = com.apply_if_callable(key, self.obj)
# --> <a href='file:///Users/waf/.pyenv/versions/3.10.3/lib/python3.10/site-packages/pandas/core/indexing.py?line=930'>931</a> return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']]
# Out:
#         week  percentage_pop_est  percentage_pop_est_lci  \
# 0    2020-18                0.27                    0.17
# 1    2020-19                0.25                    0.16
# 2    2020-20                0.24                    0.11
# 3    2020-20                0.10                    0.05
# 4    2020-22                0.06                    0.02
# ..       ...                 ...                     ...
# 134  2022-46                1.73                    1.60
# 135  2022-48                2.01                    1.87
# 136  2022-48                2.20                    2.08
# 137  2022-51                4.52                    4.29
# 138  2022-52                4.02                    3.84
#
#      percentage_pop_est_uci  pop_est  pop_est_lci  pop_est_uci
# 0                      0.41   148000        94000       222000
# 1                      0.38   137000        85000       208000
# 2                      0.46   133000        62000       250000
# ...

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']].to_csv("20230113covid19infectionsurveydatasetengland_sheet1a.csv",index=False)

# %%
df2["ons_geog_code"] = "E92000001"

# %%
df2
# Out:
#                               Time period  percentage_pop_est  \
# 0            27 April 2020 to 10 May 2020                0.27
# 1              04 May 2020 to 17 May 2020                0.25
# 2              11 May 2020 to 24 May 2020                0.24
# 3              17 May 2020 to 30 May 2020                0.10
# 4             25 May 2020 to 07 June 2020                0.06
# ..                                    ...                 ...
# 134  20 November 2022 to 26 November 2022                1.73
# 135  29 November 2022 to 05 December 2022                2.01
# 136  03 December 2022 to 09 December 2022                2.20
# 137  22 December 2022 to 28 December 2022                4.52
# 138   28 December 2022 to 03 January 2023                4.02
#
#      percentage_pop_est_lci  percentage_pop_est_uci  pop_est  pop_est_lci  \
# 0                      0.17                    0.41   148000        94000
# ...

# %%
df2[["week", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci', "ons_geog_code"]].to_csv("20230113covid19infectionsurveydatasetengland_sheet1a.csv",index=False)

# %%
df2[["week", "ons_geog_code", 'percentage_pop_est', 'percentage_pop_est_lci', 'percentage_pop_est_uci', 'pop_est', 'pop_est_lci', 'pop_est_uci']].to_csv("20230113covid19infectionsurveydatasetengland_sheet1a.csv",index=False)
